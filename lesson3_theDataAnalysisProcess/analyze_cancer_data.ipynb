# %%
import pandas as pd

df = pd.read_csv('data.csv')

# %%
df[list(df.columns)[20:30]]
# Out:
#      symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0        0.03003              0.006193        25.380          17.33
# 1        0.01389              0.003532        24.990          23.41
# 2        0.02250              0.004571        23.570          25.53
# 3        0.05963              0.009208        14.910          26.50
# 4        0.01756              0.005115        22.540          16.67
# ..           ...                   ...           ...            ...
# 564      0.01114              0.004239        25.450          26.40
# 565      0.01898              0.002498        23.690          38.25
# 566      0.01318              0.003892        18.980          34.12
# 567      0.02324              0.006185        25.740          39.42
# 568      0.02676              0.002783         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# ...

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df[df.diagnosis == 'B'][list(df.columns)[0:15]]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         B       13.540         14.36           87.46      566.3
# 20    8510653         B       13.080         15.71           85.63      520.0
# 21    8510824         B        9.504         12.44           60.34      273.9
# 37     854941         B       13.030         18.42           82.61      523.8
# 46   85713702         B        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B       14.590         22.68           96.39      657.1
# 559    925291         B       11.510         23.93           74.52      403.5
# 560    925292         B       14.050         27.15           91.38      600.4
# 561    925311         B       11.200         29.37           70.67      386.0
# 568     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
df[df.diagnosis == 'M'][list(df.columns)[15:]].describe()
# Out:
#           area_se  smoothness_se  compactness_se  concavity_se  \
# count  212.000000     212.000000      212.000000    212.000000
# mean    72.672406       0.006780        0.032281      0.041824
# std     61.355268       0.002890        0.018387      0.021603
# min     13.990000       0.002667        0.008422      0.011010
# 25%     35.762500       0.005085        0.019662      0.026998
# 50%     58.455000       0.006209        0.028590      0.037125
# 75%     94.000000       0.007971        0.038910      0.050443
# max    542.200000       0.031130        0.135400      0.143800
#
#        concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# count         212.000000   212.000000            212.000000    212.000000
# mean            0.015060     0.020472              0.004062     21.134811
# std             0.005517     0.010065              0.002041      4.283569
# min             0.005174     0.007882              0.001087     12.840000
# ...
