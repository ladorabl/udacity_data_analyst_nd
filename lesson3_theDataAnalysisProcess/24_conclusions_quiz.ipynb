# %% [markdown]
# # Drawing Conclusions Quiz
# Use the space below to explore `store_data.csv` to answer the quiz questions below.

# %%
# imports and load data
import pandas as pd
import matplotlib as plt
import seaborn as sns
import datetime
df = pd.read_csv('store_data.csv',parse_dates=['week'])
print(df.columns)
df.head()
# Out:
# Index(['week', 'storeA', 'storeB', 'storeC', 'storeD', 'storeE'], dtype='object')
#         week  storeA  storeB  storeC  storeD  storeE
# 0 2014-05-04    2643    8257    3893    6231    1294
# 1 2014-05-11    6444    5736    5634    7092    2907
# 2 2014-05-18    9646    2552    4253    5447    4736
# 3 2014-05-25    5960   10740    8264    6063     949
# 4 2014-06-01    7412    7374    3208    3985    3023

# %%
df.plot.line(x='week', y=['storeA','storeB','storeC','storeD','storeE'], figsize=(26,12));

# %%
# explore data
df.p

# %%
# total sales for the last month
df.week.max()
lastWeek = '2018-02-25 00:00:00'
lastWeek = pd.Timestamp(2018,2,25)
df = df.set_index('week')

#df[df.week == lastWeek]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-8a7d9c44abd5> in <module>()
#       1 # total sales for the last month
# ----> 2 df.week.max()
#       3 lastWeek = '2018-02-25 00:00:00'
#       4 lastWeek = pd.Timestamp(2018,2,25)
#       5 df = df.set_index('week')
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'week'

# %%
df_monthly = df.resample('M').sum()
df_monthly.tail(5)
# Out:
#             storeA  storeB  storeC  storeD  storeE
# week
# 2017-10-31   32299   44731   20535   27545    9435
# 2017-11-30   29748   27601   21520   25219    6914
# 2017-12-31   40688   29151   30198   28422    8509
# 2018-01-31   21776   25648   19893   23985   11038
# 2018-02-28   25127   24595   16447   22783    7787

# %%
# average sales
df_monthly.mean()
# Out:
# storeA    25502.086957
# storeB    29377.000000
# storeC    21487.413043
# storeD    23614.804348
# storeE    11217.500000
# dtype: float64

# %%
# sales on march 13, 2016
targetWeek = pd.Timestamp(2016,3,13)
df[df.index == targetWeek]
# Out:
#             storeA  storeB  storeC  storeD  storeE
# week
# 2016-03-13    2054    1390    5112    5513    2536

# %%
# worst week for store C
df.storeC.sort_values()
# Out:
# week
# 2014-07-06     927
# 2016-01-24    2036
# 2014-07-20    2104
# 2017-10-01    2286
# 2017-02-12    2332
# 2014-08-24    2411
# 2015-10-04    2444
# 2017-06-11    2460
# 2014-08-10    2476
# 2017-06-04    2595
# 2014-10-26    2878
# 2014-12-28    2932
# 2015-05-17    2972
# 2016-09-25    3046
# 2017-08-27    3049
# 2016-10-02    3049
# 2017-05-07    3083
# 2016-04-17    3091
# 2017-04-09    3144
# 2015-01-11    3145
# 2015-06-14    3164
# 2014-06-29    3199
# 2014-06-01    3208
# 2016-07-17    3390
# 2015-09-06    3568
# 2018-02-25    3569
# 2015-02-15    3591
# 2016-03-20    3601
# 2014-12-14    3661
# 2016-11-20    3669
#               ...
# 2017-12-24    6240
# 2014-10-19    6261
# 2017-09-24    6320
# 2015-02-08    6330
# 2015-12-27    6333
# 2017-07-30    6340
# 2015-03-22    6446
# 2015-11-29    6503
# 2017-01-01    6608
# 2014-11-09    6616
# 2017-05-14    6688
# 2017-12-31    6711
# 2015-09-27    6715
# 2016-10-16    6751
# 2015-08-02    6777
# 2014-12-21    6877
# ...

# %%
# total sales during most recent 3 month period
df_quarterly = df.resample('3M').sum()
print(df_quarterly.idxmax(axis=1).tail())
df_quarterly.max(axis=1).tail()
# Out:
# week
# 2017-02-28    storeB
# 2017-05-31    storeA
# 2017-08-31    storeB
# 2017-11-30    storeB
# 2018-02-28    storeA
# dtype: object
# week
# 2017-02-28     88205
# 2017-05-31     86209
# 2017-08-31    101326
# 2017-11-30    103704
# 2018-02-28     87591
# dtype: int64

# %%
df_monthly.tail(5)
# Out:
#             storeA  storeB  storeC  storeD  storeE
# week
# 2017-10-31   32299   44731   20535   27545    9435
# 2017-11-30   29748   27601   21520   25219    6914
# 2017-12-31   40688   29151   30198   28422    8509
# 2018-01-31   21776   25648   19893   23985   11038
# 2018-02-28   25127   24595   16447   22783    7787
