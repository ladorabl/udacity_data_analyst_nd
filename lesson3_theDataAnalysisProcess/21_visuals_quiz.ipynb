# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below. Remember, you created this dataset at the bottom of the notebook in the "Reading CSV Files" section earlier in the lesson! Check your work with the solutions on that page if you are having trouble getting this dataset.

# %%
# import and load data
import pandas as pd
import numpy as np
import matplotlib as plt

df = pd.read_csv('powerplant_data_edited.csv')
df
# Out:
#       Average_Temperature  Exhaust_Vacuum  Ambient_Pressure  \
# 0                    8.34           40.77           1010.84
# 1                   23.64           58.49           1011.40
# 2                   29.74           56.90           1007.15
# 3                   19.07           49.69           1007.22
# 4                   11.80           40.66           1017.13
# 5                   13.97           39.16           1016.05
# 6                   22.10           71.29           1008.20
# 7                   14.47           41.76           1021.98
# 8                   31.25           69.51           1010.25
# 9                    6.77           38.18           1017.80
# 10                  28.28           68.67           1006.36
# 11                  22.99           46.93           1014.15
# 12                  29.30           70.04           1010.95
# 13                   8.14           37.49           1009.04
# 14                  16.92           44.60           1017.34
# ...

# %%
# plot relationship between temperature and electrical output
df.plot(x='Average_Temperature',y='Energy_Output', kind='scatter',figsize=(12,12));

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15));

# %%
df.describe()
# Out:
#        Average_Temperature  Exhaust_Vacuum  Ambient_Pressure  \
# count          9568.000000     9568.000000       9568.000000
# mean             19.651231       54.305804       1013.259078
# std               7.452473       12.707893          5.938784
# min               1.810000       25.360000        992.890000
# 25%              13.510000       41.740000       1009.100000
# 50%              20.345000       52.080000       1012.940000
# 75%              25.720000       66.540000       1017.260000
# max              37.110000       81.560000       1033.300000
#
#        Relative_Humidity  Energy_Output
# count        9568.000000    9568.000000
# mean           73.308978     454.365009
# std            14.600269      17.066995
# min            25.560000     420.260000
# 25%            63.327500     439.750000
# 50%            74.975000     451.550000
# 75%            84.830000     468.430000
# max           100.160000     495.760000

# %%
# plot distribution of humidity
#df['Relative_Humidity'].hist(figsize=(12,12));
df.plot(x='Energy_Output', y='Relative_Humidity', kind='hist', figsize=(12,12) );

# %%
df.columns
# Out:
# Index(['Average_Temperature', 'Exhaust_Vacuum', 'Ambient_Pressure',
#        'Relative_Humidity', 'Energy_Output'],
#       dtype='object')

# %%
# plot box plots for each variable
df[df.columns[0]].plot(kind='box',figsize=(8,8));

# %%
df[df.columns[1]].plot(kind='box',figsize=(8,8));

# %%
df[df.columns[2]].plot(kind='box',figsize=(8,8));

# %%
df_stats = df.describe()
df_stats
# Out:
#        Average_Temperature  Exhaust_Vacuum  Ambient_Pressure  \
# count          9568.000000     9568.000000       9568.000000
# mean             19.651231       54.305804       1013.259078
# std               7.452473       12.707893          5.938784
# min               1.810000       25.360000        992.890000
# 25%              13.510000       41.740000       1009.100000
# 50%              20.345000       52.080000       1012.940000
# 75%              25.720000       66.540000       1017.260000
# max              37.110000       81.560000       1033.300000
#
#        Relative_Humidity  Energy_Output
# count        9568.000000    9568.000000
# mean           73.308978     454.365009
# std            14.600269      17.066995
# min            25.560000     420.260000
# 25%            63.327500     439.750000
# 50%            74.975000     451.550000
# 75%            84.830000     468.430000
# max           100.160000     495.760000

# %%
df_stats.loc['75%']
# Out:
# Average_Temperature      25.72
# Exhaust_Vacuum           66.54
# Ambient_Pressure       1017.26
# Relative_Humidity        84.83
# Energy_Output           468.43
# Name: 75%, dtype: float64

# %%
df_stats.loc['25%']
# Out:
# Average_Temperature      13.5100
# Exhaust_Vacuum           41.7400
# Ambient_Pressure       1009.1000
# Relative_Humidity        63.3275
# Energy_Output           439.7500
# Name: 25%, dtype: float64

# %%
df_stats.loc['75%'] - df_stats.loc['25%']
# Out:
# Average_Temperature    12.2100
# Exhaust_Vacuum         24.8000
# Ambient_Pressure        8.1600
# Relative_Humidity      21.5025
# Energy_Output          28.6800
# dtype: float64

# %%
rh_q3, rh_q1 = np.percentile(df['Relative_Humidity'], [75, 25])
rh_iqr = rh_q3 - rh_q1
print('RH\nQ3 : {0}\nQ1 : {1}\nIQR : {2}'.format(rh_q3,  rh_q1, rh_iqr))
# Out:
# RH
# Q3 : 84.83
# Q1 : 63.3275
# IQR : 21.502499999999998

# %%
outerlier_threshold_rh_q1 = ap_q1 - 1.5 * rh_iqr
outerlier_threshold_rh_q1
# Out:
# 31.073750000000004

# %%
outerlier_threshold_rh_q3 = ap_q3 + 1.5 * rh_iqr
outerlier_threshold_rh_q3
# Out:
# 117.08374999999999

# %%
df[['Ambient_Pressure']][(df['Ambient_Pressure'] > outerlier_threshold_ap_q3) | (df['Ambient_Pressure'] < outerlier_threshold_ap_q1)].shape
# Out:
# (88, 1)

# %%
df[['Relative_Humidity']][(df['Relative_Humidity'] > outerlier_threshold_rh_q3) | (df['Relative_Humidity'] < outerlier_threshold_rh_q1)].shape
# Out:
# (12, 1)

# %%
df[df.columns[3]].plot(kind='box',figsize=(8,8));

# %%
print(df.columns)
# ambient presssure and relative humidity have alot of outliers
# Out:
# Index(['Average_Temperature', 'Exhaust_Vacuum', 'Ambient_Pressure',
#        'Relative_Humidity', 'Energy_Output'],
#       dtype='object')

# %%
q3
# Out:
# 1017.26

# %%
q1
# Out:
# 1009.1

# %%
iqr = q3-q1
iqr
# Out:
# 8.1599999999999682

# %%
df.describe()
# Out:
#        Average_Temperature  Exhaust_Vacuum  Ambient_Pressure  \
# count          9568.000000     9568.000000       9568.000000
# mean             19.651231       54.305804       1013.259078
# std               7.452473       12.707893          5.938784
# min               1.810000       25.360000        992.890000
# 25%              13.510000       41.740000       1009.100000
# 50%              20.345000       52.080000       1012.940000
# 75%              25.720000       66.540000       1017.260000
# max              37.110000       81.560000       1033.300000
#
#        Relative_Humidity  Energy_Output
# count        9568.000000    9568.000000
# mean           73.308978     454.365009
# std            14.600269      17.066995
# min            25.560000     420.260000
# 25%            63.327500     439.750000
# 50%            74.975000     451.550000
# 75%            84.830000     468.430000
# max           100.160000     495.760000
